# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %%
def step_gradient(x, y, learning_rate, m):
    k = x.shape[0]
    l = x.shape[1]
    slope_m = np.zeros(l)
    for i in range(k):
        for j in range(l):
            slope_m[j] += (2/k)*x[i][j]*((x[i].dot(m)) - y[i])
        #if i%32 == 0:
    m = m - learning_rate*slope_m
            #slope_m = np.zeros(l)
    return m

def cost(x, y, m):
    return ((y-(x.dot(m)))**2).mean()

def gradient_descent(x,y, learning_rate, num_iter):
    m = np.zeros(x.shape[1])
    print('start: ', cost(x,y,m))
    for i in range(num_iter):
        m = step_gradient(x,y, learning_rate, m)
        if i%10 == 0:
            print(i, " : ", cost(x,y,m))
    return m

def run(x,y):
    learning_rate = 0.1
    num_iter = 5000
    m = gradient_descent(x,y,learning_rate,num_iter)
    return m

# %%
dataset = np.genfromtxt('Gradient Descent-Combined_Cycle_Power_Plant_Train.csv', delimiter=',')
x_train = dataset[:,:-1]
y_train = dataset[:,-1]
x_test = np.genfromtxt('Gradient Descent-Combined_Cycle_Power_Plant_Test.csv', delimiter=',')
df_train = pd.DataFrame(x_train)
df_test = pd.DataFrame(x_test)

i = 0
n = len(df_train.columns)
l = df_train.columns
while i < n:
    j = i
    while j < n:
        df_train[str(l[i]) + '*' + str(l[j])] = df_train[l[i]]*df_train[l[j]]
        j += 1
    i += 1
    
i = 0
n = len(df_test.columns)
l = df_test.columns
while i < n:
    j = i
    while j < n:
        df_test[str(l[i]) + '*' + str(l[j])] = df_test[l[i]]*df_test[l[j]]
        j += 1
    i += 1

x_train = np.array(df_train)
x_test = np.array(df_test)

# %%
x_test.shape, x_train.shape
# Out:
# ((2392, 14), (7176, 14))

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# for i in range(len(x_train[0])):
#     std = np.sqrt(((x_train[:,i] - x_train[:,i].mean())**2).mean())
#     x_train[:, i] = (x_train[:, i] - x_train[:, i].mean())/ std

# for i in range(len(x_test[0])):
#     std = np.sqrt(((x_test[:,i] - x_test[:,i].mean())**2).mean())
#     x_test[:, i] = (x_test[:, i] - x_test[:, i].mean())/ std

#for i in range(len(x_train[0])):
#    x_train[:, i] = (x_train[:, i] - x_train[:, i].mean()) / (max(x_train[:, i]) - min(x_train[:, i]))
    
#for i in range(len(x_test[0])):
#    x_test[:, i] = (x_test[:, i] - x_test[:, i].mean()) / (max(x_test[:, i]) - min(x_test[:, i]))

#for i in range(len(x_train[0])):
#    x_train[:, i] = (x_train[:, i] - min(x_train[:, i])) / (max(x_train[:, i]) - min(x_train[:, i]))
    
#for i in range(len(x_test[0])):
#    x_test[:, i] = (x_test[:, i] - min(x_test[:, i])) / (max(x_test[:, i]) - min(x_test[:, i]))

# x_train = preprocessing.scale(x_train)
# x_test = preprocessing.scale(x_test)

# %%
x_train = np.insert(x_train, 0, 1, axis = 1)
x_test = np.insert(x_test, 0, 1, axis = 1)

# %%
m = run(x_train, y_train)
# Out:
# start:  206801.35285512818
# 0  :  132332.2853383264
# 10  :  1546.4591718490108
# 20  :  38.71413286173015
# 30  :  20.9435430435767
# 40  :  20.535679206229872
# 50  :  20.385017886628198
# 60  :  20.264795253107838
# 70  :  20.162793249510848
# 80  :  20.074089150789458
# 90  :  19.995565897620818
# 100  :  19.925041319291026
# 110  :  19.860938795927108
# 120  :  19.802102920421707
# 130  :  19.747677463498402
# 140  :  19.69702021695152
# 150  :  19.649642696148536
# 160  :  19.60516726438213
# 170  :  19.563296595484978
# 180  :  19.523791899146712
# 190  :  19.486457374879315
# 200  :  19.45112909513685
# 210  :  19.41766703902891
# 220  :  19.385949368034197
# 230  :  19.355868297967135
# 240  :  19.327327108213037
# 250  :  19.300237961954892
# 260  :  19.274520305412953
# 270  :  19.250099681130322
# 280  :  19.226906837956076
# 290  :  19.20487705421902
# 300  :  19.183949614638045
# 310  :  19.164067398610193
# 320  :  19.14517654967039
# 330  :  19.12722620455726
# 340  :  19.11016826646395
# 350  :  19.093957211423866
# 360  :  19.078549919890943
# 370  :  19.063905527789753
# 380  :  19.04998529288685
# 390  :  19.036752473460997
# 400  :  19.02417221705316
# 410  :  19.012211457650118
# 420  :  19.00083882006926
# 430  :  18.99002453060563
# 440  :  18.97974033321747
# 450  :  18.969959410679362
# 460  :  18.960656310245664
# 470  :  18.95180687344949
# 480  :  18.94338816972275
# 490  :  18.93537843357038
# 500  :  18.92775700506528
# 510  :  18.920504273458043
# 520  :  18.913601623717135
# 530  :  18.907031385831633
# 540  :  18.900776786722727
# 550  :  18.89482190462198
# 560  :  18.88915162578464
# 570  :  18.883751603413728
# 580  :  18.878608218680235
# 590  :  18.8737085437295
# 600  :  18.869040306571684
# 610  :  18.864591857759322
# 620  :  18.860352138760113
# 630  :  18.85631065193821
# 640  :  18.852457432062035
# 650  :  18.848783019260356
# 660  :  18.845278433353368
# 670  :  18.84193514948808
# 680  :  18.838745075012124
# 690  :  18.835700527522796
# 700  :  18.83279421403153
# 710  :  18.83001921118707
# 720  :  18.827368946503697
# 730  :  18.824837180543003
# 740  :  18.822417990001412
# 750  :  18.820105751656538
# 760  :  18.817895127129567
# 770  :  18.815781048421698
# 780  :  18.81375870418543
# 790  :  18.811823526693335
# 800  :  18.809971179468914
# 810  :  18.808197545545895
# 820  :  18.806498716324025
# 830  :  18.804870980990852
# 840  :  18.803310816481275
# 850  :  18.80181487794676
# 860  :  18.800379989708997
# 870  :  18.799003136673154
# 880  :  18.797681456177088
# 890  :  18.79641223025499
# 900  :  18.795192878293527
# 910  :  18.794020950061686
# 920  :  18.792894119094015
# 930  :  18.791810176410575
# 940  :  18.790767024555294
# 950  :  18.78976267193788
# 960  :  18.788795227462277
# 970  :  18.787862895428763
# 980  :  18.786963970694423
# 990  :  18.786096834079697
# 1000  :  18.785259948008132
# 1010  :  18.784451852367685
# 1020  :  18.783671160582145
# 1030  :  18.782916555882018
# 1040  :  18.782186787765
# 1050  :  18.781480668635997
# 1060  :  18.78079707061792
# 1070  :  18.7801349225243
# 1080  :  18.779493206985855
# 1090  :  18.778870957722663
# 1100  :  18.778267256955225
# 1110  :  18.77768123294657
# 1120  :  18.777112057669523
# 1130  :  18.77655894459224
# 1140  :  18.776021146576163
# 1150  :  18.775497953880702
# 1160  :  18.77498869226945
# 1170  :  18.7744927212121
# 1180  :  18.774009432178026
# 1190  :  18.77353824701632
# 1200  :  18.77307861641812
# 1210  :  18.772630018456898
# 1220  :  18.77219195720288
# 1230  :  18.771763961407988
# 1240  :  18.771345583257155
# 1250  :  18.77093639718321
# 1260  :  18.77053599874211
# 1270  :  18.77014400354482
# 1280  :  18.769760046243658
# 1290  :  18.769383779570106
# 1300  :  18.769014873421376
# 1310  :  18.76865301399311
# 1320  :  18.76829790295651
# 1330  :  18.76794925667684
# 1340  :  18.767606805471726
# 1350  :  18.767270292907103
# 1360  :  18.76693947512876
# 1370  :  18.7666141202279
# 1380  :  18.76629400763873
# 1390  :  18.765978927566888
# 1400  :  18.76566868044639
# 1410  :  18.765363076424546
# 1420  :  18.765061934872747
# 1430  :  18.76476508392217
# 1440  :  18.764472360022914
# 1450  :  18.764183607525503
# 1460  :  18.763898678283706
# 1470  :  18.7636174312773
# 1480  :  18.763339732254142
# 1490  :  18.763065453390183
# 1500  :  18.76279447296689
# 1510  :  18.76252667506476
# 1520  :  18.762261949272734
# 1530  :  18.762000190411882
# 1540  :  18.761741298273403
# 1550  :  18.76148517736981
# 1560  :  18.761231736698534
# 1570  :  18.76098088951778
# 1580  :  18.76073255313359
# 1590  :  18.760486648697466
# 1600  :  18.760243101014723
# 1610  :  18.76000183836201
# 1620  :  18.75976279231439
# 1630  :  18.759525897581103
# 1640  :  18.759291091849526
# 1650  :  18.759058315637105
# 1660  :  18.758827512150773
# 1670  :  18.75859862715342
# 1680  :  18.75837160883716
# 1690  :  18.75814640770296
# 1700  :  18.757922976446398
# 1710  :  18.75770126984906
# 1720  :  18.757481244675596
# 1730  :  18.75726285957582
# 1740  :  18.757046074991873
# 1750  :  18.75683085306991
# 1760  :  18.756617157576382
# 1770  :  18.756404953818496
# 1780  :  18.756194208568637
# 1790  :  18.755984889992657
# 1800  :  18.75577696758174
# 1810  :  18.75557041208759
# 1820  :  18.75536519546125
# 1830  :  18.755161290794472
# 1840  :  18.754958672264433
# 1850  :  18.75475731508109
# 1860  :  18.754557195437123
# 1870  :  18.754358290460573
# 1880  :  18.754160578169632
# 1890  :  18.75396403742977
# 1900  :  18.753768647913226
# 1910  :  18.75357439006017
# 1920  :  18.753381245042096
# 1930  :  18.753189194726914
# 1940  :  18.752998221645793
# 1950  :  18.752808308961722
# 1960  :  18.752619440439577
# 1970  :  18.752431600417783
# 1980  :  18.75224477378118
# 1990  :  18.75205894593555
# 2000  :  18.751874102783095
# 2010  :  18.751690230699463
# 2020  :  18.751507316511486
# 2030  :  18.751325347476556
# 2040  :  18.751144311262607
# 2050  :  18.750964195929217
# 2060  :  18.750784989909704
# 2070  :  18.750606681994093
# 2080  :  18.750429261312913
# 2090  :  18.750252717321693
# 2100  :  18.75007703978642
# 2110  :  18.74990221876959
# 2120  :  18.749728244616918
# 2130  :  18.749555107944804
# 2140  :  18.749382799628396
# 2150  :  18.749211310790137
# 2160  :  18.74904063278897
# 2170  :  18.748870757210092
# 2180  :  18.748701675855138
# 2190  :  18.74853338073287
# 2200  :  18.748365864050285
# 2210  :  18.7481991182044
# 2220  :  18.748033135773827
# 2230  :  18.747867909511683
# 2240  :  18.747703432337836
# 2250  :  18.74753969733241
# 2260  :  18.747376697728907
# 2270  :  18.7472144269082
# 2280  :  18.747052878392406
# 2290  :  18.746892045839363
# 2300  :  18.746731923037043
# 2310  :  18.746572503898744
# 2320  :  18.746413782457857
# 2330  :  18.746255752863394
# 2340  :  18.746098409375566
# 2350  :  18.745941746361535
# 2360  :  18.745785758291245
# 2370  :  18.74563043973391
# 2380  :  18.74547578535401
# 2390  :  18.745321789908054
# 2400  :  18.745168448241206
# 2410  :  18.74501575528398
# 2420  :  18.744863706049472
# 2430  :  18.744712295630293
# 2440  :  18.744561519195866
# 2450  :  18.744411371989873
# 2460  :  18.744261849327682
# 2470  :  18.744112946594043
# 2480  :  18.743964659240714
# 2490  :  18.74381698278436
# 2500  :  18.743669912804513
# 2510  :  18.74352344494151
# 2520  :  18.74337757489459
# 2530  :  18.743232298420242
# 2540  :  18.743087611330303
# 2550  :  18.742943509490402
# 2560  :  18.742799988818355
# 2570  :  18.742657045282687
# 2580  :  18.742514674901116
# 2590  :  18.74237287373928
# 2600  :  18.742231637909367
# 2610  :  18.74209096356879
# 2620  :  18.741950846919067
# 2630  :  18.7418112842046
# 2640  :  18.74167227171167
# 2650  :  18.741533805767236
# 2660  :  18.74139588273798
# 2670  :  18.74125849902932
# 2680  :  18.741121651084537
# 2690  :  18.740985335383787
# 2700  :  18.740849548443204
# 2710  :  18.740714286814303
# 2720  :  18.74057954708284
# 2730  :  18.740445325868365
# 2740  :  18.740311619823277
# 2750  :  18.74017842563226
# 2760  :  18.74004574001145
# 2770  :  18.739913559707954
# 2780  :  18.739781881499095
# 2790  :  18.739650702191877
# 2800  :  18.739520018622382
# 2810  :  18.7393898276552
# 2820  :  18.739260126182874
# 2830  :  18.73913091112544
# 2840  :  18.739002179429882
# 2850  :  18.73887392806967
# 2860  :  18.738746154044176
# 2870  :  18.738618854378494
# 2880  :  18.738492026122678
# 2890  :  18.73836566635154
# 2900  :  18.738239772164224
# 2910  :  18.73811434068368
# 2920  :  18.73798936905644
# 2930  :  18.73786485445217
# 2940  :  18.73774079406329
# 2950  :  18.73761718510469
# 2960  :  18.737494024813387
# 2970  :  18.737371310448108
# 2980  :  18.737249039289168
# 2990  :  18.737127208637933
# 3000  :  18.737005815816712
# 3010  :  18.73688485816835
# 3020  :  18.736764333056016
# 3030  :  18.736644237862873
# 3040  :  18.736524569991936
# 3050  :  18.736405326865626
# 3060  :  18.736286505925666
# 3070  :  18.736168104632814
# 3080  :  18.736050120466572
# 3090  :  18.73593255092499
# 3100  :  18.735815393524486
# 3110  :  18.735698645799523
# 3120  :  18.735582305302515
# 3130  :  18.7354663696035
# 3140  :  18.73535083628999
# 3150  :  18.735235702966833
# 3160  :  18.735120967255963
# 3170  :  18.73500662679614
# 3180  :  18.73489267924285
# 3190  :  18.734779122268193
# 3200  :  18.734665953560533
# 3210  :  18.734553170824412
# 3220  :  18.734440771780452
# 3230  :  18.73432875416505
# 3240  :  18.734217115730313
# 3250  :  18.734105854243843
# 3260  :  18.73399496748864
# 3270  :  18.73388445326288
# 3280  :  18.733774309379857
# 3290  :  18.733664533667717
# 3300  :  18.733555123969367
# 3310  :  18.733446078142403
# 3320  :  18.7333373940589
# 3330  :  18.73322906960521
# 3340  :  18.73312110268196
# 3350  :  18.733013491203895
# 3360  :  18.732906233099623
# 3370  :  18.73279932631162
# 3380  :  18.732692768796106
# 3390  :  18.732586558522833
# 3400  :  18.732480693475
# 3410  :  18.732375171649167
# 3420  :  18.73226999105512
# 3430  :  18.73216514971573
# 3440  :  18.73206064566687
# 3450  :  18.73195647695727
# 3460  :  18.73185264164848
# 3470  :  18.7317491378146
# 3480  :  18.731645963542405
# 3490  :  18.73154311693106
# 3500  :  18.73144059609204
# 3510  :  18.731338399149124
# 3520  :  18.731236524238152
# 3530  :  18.73113496950708
# 3540  :  18.73103373311576
# 3550  :  18.73093281323589
# 3560  :  18.7308322080509
# 3570  :  18.73073191575588
# 3580  :  18.730631934557472
# 3590  :  18.730532262673808
# 3600  :  18.730432898334364
# 3610  :  18.730333839779913
# 3620  :  18.73023508526241
# 3630  :  18.73013663304493
# 3640  :  18.73003848140155
# 3650  :  18.72994062861732
# 3660  :  18.72984307298808
# 3670  :  18.729745812820514
# 3680  :  18.7296488464319
# 3690  :  18.72955217215016
# 3700  :  18.729455788313757
# 3710  :  18.729359693271576
# 3720  :  18.72926388538285
# 3730  :  18.729168363017113
# 3740  :  18.729073124554088
# 3750  :  18.728978168383666
# 3760  :  18.728883492905734
# 3770  :  18.728789096530228
# 3780  :  18.728694977676923
# 3790  :  18.728601134775474
# 3800  :  18.728507566265254
# 3810  :  18.728414270595394
# 3820  :  18.72832124622455
# 3830  :  18.72822849162102
# 3840  :  18.72813600526251
# 3850  :  18.728043785636157
# 3860  :  18.727951831238464
# 3870  :  18.72786014057516
# 3880  :  18.727768712161264
# 3890  :  18.727677544520812
# 3900  :  18.727586636187052
# 3910  :  18.72749598570214
# 3920  :  18.727405591617227
# 3930  :  18.727315452492345
# 3940  :  18.72722556689637
# 3950  :  18.72713593340684
# 3960  :  18.727046550610133
# 3970  :  18.72695741710117
# 3980  :  18.726868531483458
# 3990  :  18.726779892369063
# 4000  :  18.72669149837843
# 4010  :  18.726603348140504
# 4020  :  18.72651544029248
# 4030  :  18.726427773479877
# 4040  :  18.726340346356462
# 4050  :  18.726253157584107
# 4060  :  18.726166205832843
# 4070  :  18.726079489780766
# 4080  :  18.725993008113914
# 4090  :  18.72590675952636
# 4100  :  18.725820742719968
# 4110  :  18.72573495640454
# 4120  :  18.72564939929759
# 4130  :  18.72556407012438
# 4140  :  18.725478967617907
# 4150  :  18.725394090518737
# 4160  :  18.725309437574996
# 4170  :  18.725225007542427
# 4180  :  18.72514079918415
# 4190  :  18.72505681127079
# 4200  :  18.724973042580274
# 4210  :  18.724889491897898
# 4220  :  18.724806158016243
# 4230  :  18.724723039735117
# 4240  :  18.724640135861474
# 4250  :  18.72455744520947
# 4260  :  18.724474966600233
# 4270  :  18.724392698862072
# 4280  :  18.724310640830204
# 4290  :  18.72422879134674
# 4300  :  18.72414714926087
# 4310  :  18.724065713428455
# 4320  :  18.723984482712286
# 4330  :  18.723903455981816
# 4340  :  18.723822632113354
# 4350  :  18.723742009989778
# 4360  :  18.723661588500615
# 4370  :  18.723581366542064
# 4380  :  18.72350134301679
# 4390  :  18.723421516833948
# 4400  :  18.72334188690926
# 4410  :  18.72326245216477
# 4420  :  18.72318321152895
# 4430  :  18.723104163936597
# 4440  :  18.72302530832886
# 4450  :  18.72294664365301
# 4460  :  18.722868168862703
# 4470  :  18.722789882917656
# 4480  :  18.72271178478378
# 4490  :  18.722633873433043
# 4500  :  18.722556147843523
# 4510  :  18.722478606999278
# 4520  :  18.722401249890364
# 4530  :  18.72232407551277
# 4540  :  18.72224708286845
# 4550  :  18.722170270965144
# 4560  :  18.722093638816457
# 4570  :  18.722017185441807
# 4580  :  18.721940909866348
# 4590  :  18.721864811120987
# 4600  :  18.721788888242266
# 4610  :  18.721713140272417
# 4620  :  18.721637566259265
# 4630  :  18.721562165256252
# 4640  :  18.721486936322297
# 4650  :  18.721411878521888
# 4660  :  18.72133699092498
# 4670  :  18.721262272606896
# 4680  :  18.721187722648448
# 4690  :  18.721113340135833
# 4700  :  18.721039124160534
# 4710  :  18.720965073819283
# 4720  :  18.720891188214228
# 4730  :  18.72081746645267
# 4740  :  18.72074390764709
# 4750  :  18.720670510915205
# 4760  :  18.72059727537985
# 4770  :  18.720524200168978
# 4780  :  18.720451284415603
# 4790  :  18.720378527257772
# 4800  :  18.720305927838616
# 4810  :  18.72023348530616
# 4820  :  18.720161198813432
# 4830  :  18.720089067518426
# 4840  :  18.720017090583912
# 4850  :  18.7199452671776
# 4860  :  18.71987359647208
# 4870  :  18.719802077644623
# 4880  :  18.71973070987739
# 4890  :  18.719659492357216
# 4900  :  18.719588424275635
# 4910  :  18.71951750482894
# 4920  :  18.719446733218025
# 4930  :  18.719376108648415
# 4940  :  18.7193056303303
# 4950  :  18.719235297478363
# 4960  :  18.719165109311827
# 4970  :  18.71909506505453
# 4980  :  18.719025163934646
# 4990  :  18.718955405184946

# %%
y_pred = x_test.dot(m)

# %%
np.savetxt('CCPP_y_pred.csv', y_pred, delimiter=',')
